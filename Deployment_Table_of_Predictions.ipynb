# %%
# import libraries
from tensorflow.keras.models import load_model
import pandas as pd
import glob
import numpy as np 

np.random.seed(305)

# %%
load = pd.read_csv('employment_cube_june19.TXT', low_memory=False)
load.shape
# Out:
# (2123146, 19)

# %%
load.head()
# Out:
#   AGYSUB LOC AGELVL EDLVL GSEGRD LOSLVL   OCC  PATCO  PPGRD SALLVL STEMOCC  \
# 0   AA00  11      D    15     14      C  0905      1  GS-14      L    XXXX
# 1   AA00  11      E    14     14      D  0905      1  GS-14      K    XXXX
# 2   AA00  11      I    18     14      A  0905      1  GS-14      K    XXXX
# 3   AA00  11      E    13    NaN      F  0340      2  ES-**      Q    XXXX
# 4   AA00  11      D    15     14      D  0905      1  GS-14      K    XXXX
#
#   SUPERVIS TOA WORKSCH  WORKSTAT  DATECODE  EMPLOYMENT    SALARY   LOS
# 0        8  30       F         1    201906           1  125005.0   4.8
# 1        8  30       F         1    201906           1  117191.0   8.5
# 2        8  40       F         2    201906           1  117191.0   0.3
# 3        2  50       F         1    201906           1  176900.0  16.0
# 4        8  30       F         1    201906           1  117191.0   7.8

# %%
def load_emp_fact(path):

    df_total = pd.read_csv(path ,dtype={ 'AGYSUB': str, 'LOC': str, 'AGELVL': str, 'EDLVL': str, 'GSEGRD': str, 'LOSLVL': str, 'OCC': str, 'PATCO': int,
   'PPGRD': str, 'SALLVL': str, 'STEMOCC': str, 'SUPERVIS': str, 'TOA': str, 'WORKSCH': str, 'WORKSTAT': str,
   'DATECODE': str, 'EMPLOYMENT': str, 'SALARY': str, 'LOS': float})    

    #clean salary col cast to integer
    df_total['SALARY'] = df_total['SALARY'].str.replace('$','')
    df_total['SALARY'] = df_total['SALARY'].str.replace(',','')

    df_total = df_total.dropna(axis = 0, how = 'any')

    df_total['SALARY'] = df_total['SALARY'].astype(int)
    
    df_total.drop(['EDLVL', 'EMPLOYMENT', 'STEMOCC', 'SUPERVIS', 'WORKSTAT'], axis = 1 ,inplace = True)
    
    return df_total

# %%
cube_clean = load_emp_fact('employment_cube_june19.TXT')
cube_clean.head()
# Out:
#   AGYSUB LOC AGELVL GSEGRD LOSLVL   OCC  PATCO  PPGRD SALLVL TOA WORKSCH  \
# 0   AA00  11      D     14      C  0905      1  GS-14      L  30       F
# 1   AA00  11      E     14      D  0905      1  GS-14      K  30       F
# 2   AA00  11      I     14      A  0905      1  GS-14      K  40       F
# 4   AA00  11      D     14      D  0905      1  GS-14      K  30       F
# 6   AA00  11      E     15      D  0905      1  GS-15      P  30       F
#
#   DATECODE  SALARY  LOS
# 0   201906  125005  4.8
# 1   201906  117191  8.5
# 2   201906  117191  0.3
# 4   201906  117191  7.8
# 6   201906  165417  9.8

# %%
refData = 'C:/Users/604070/Desktop/Files/Performance/OPM_HR_Analytics/Model_Development/Data/REF_Tables/*'

def load_dim_table():

    '''load reference tables
    
    Output: returns a list containing dataframes of each reference table '''

    ref_list = []

    for name in glob.glob(refData):

        ref_list.append(pd.read_csv(name))

    return ref_list  


def join_func( df, df_other):
    
    '''Input: two inputs... df a given dataframe ... df_other a given dataframe to be joined to df
       
       Output: Returns a dataframe containing containing both input dataframes '''

    df = df.merge(df_other)

    return df


def joins(df):
    
    '''Inputs: df- dataframe to join reference tables; data - flag used to specify which refrence tables to join
    
       Output: Returns dataframe joined to reference tables'''
    
    #indexing based on number and order of reference tables found in the directory

    dim = load_dim_table()

    acc = dim[0]
    age = dim[1]
    agency = dim[2]
    education = dim[4]
    date = dim[5]
    grade = dim[6][1:]
    location = dim[7]
    los = dim[8]
    occ = dim[9]
    patco = dim[10]
    paygroup = dim[11]
    salary = dim[12]
    separation = dim[13]
    stem = dim[14]
    supervisor = dim[15]  
    toa = dim[16]
    workstat = dim[17]
    worksch = dim[18]

    # load fact table 

    df_join = df
    
    df_join = join_func(df_join, patco)

    df_join = join_func(df_join, age)

    df_join = join_func(df_join, agency)    

    df_join = join_func(df_join, location)

    df_join = join_func(df_join, los)

    df_join = join_func(df_join, paygroup)

    df_join = join_func(df_join, salary)

    df_join = join_func(df_join, toa)

    df_join = join_func(df_join, worksch)

    df_join = join_func(df_join, occ)
    
    x = df_join.loc[:,('AGELVLT', 'AGYSUBT', 'AGYT', 'AGYTYPT','GSEGRD','LOCT',
       'LOCTYPT', 'LOSLVLT', 'OCCFAMT', 'OCCT' , 'PATCOT', 'PAYPLANT', 'PPGRD' ,'PPGROUPT', 'QTRT',
        'SALLVLT','TOAT', 'TOATYPT', 'WORKSCHT', 'WSTYPT', 'Year', 'Month')]

    return x

# %%
df = joins(cube_clean)
df.shape
# Out:
# C:\Users\604070\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:868: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_lowerdim(tup)
# (1259087, 22)

# %%
def df_time(length, distr):
    
    rn = np.arange(1,13)
    uni = [1/12]*12
    hist = [0.11296113266468223,
     0.10026245351832906,
     0.09717002656371118,
     0.08925156128731015,
     0.08850775807969499,
     0.08713398925006596,
     0.07744573540768568,
     0.07673328577237595,
     0.07551580244162327,
     0.0719665780566477,
     0.06507940412777015,
     0.05797227283010367]

    if distr == 'uniform':
        prob = uni
    else:
        prob = hist
    
    month = pd.DataFrame(np.random.choice(rn, length, replace=True, p = prob))
    
    return month

# %%
def time_features(rows, distr):
    
    time_df = pd.DataFrame()
    
    mon_abv = {1: "JAN", 2: "FEB", 3: "MAR", 4: "APR",
               5: "MAY", 6: "JUN", 7: "JUL", 8: "AUG", 
               9: "SEP", 10: "OCT", 11: "NOV", 12: "DEC"}

    qtr_abv = {"JAN": 'JAN-MAR', "FEB": 'JAN-MAR', "MAR": 'JAN-MAR',
               'APR': 'APR-JUN', 'MAY': 'APR-JUN', 'JUN': 'APR-JUN', 
               'JUL': 'JUL-SEP', 'AUG': 'JUL-SEP', 'SEP': 'JUL-SEP', 
               'OCT': 'OCT-DEC', 'NOV': 'OCT-DEC', 'DEC': 'OCT-DEC'}
    
    time_index = df_time(rows, distr)
    
    time_df['Month_rp'] = time_index.iloc[:,0].map(mon_abv)
    
    time_df['Year_rp'] = '2017'
    
    time_df['QTRT_rp'] = time_df.iloc[:,0].map(qtr_abv)
    
    return time_df

# %%
df_t_uniform = time_features(df.shape[0], 'uniform')

# %%
df_t_historical = time_features(df.shape[0], 'historical')

# %%
df_t_uniform['Month_rp'].value_counts()
# Out:
# JAN    105387
# NOV    105382
# AUG    105090
# MAR    105047
# JUL    105047
# DEC    104972
# APR    104970
# MAY    104807
# JUN    104795
# SEP    104742
# OCT    104671
# FEB    104177
# Name: Month_rp, dtype: int64

# %%
df_t_historical['Month_rp'].value_counts()
# Out:
# JAN    142761
# FEB    126486
# MAR    122240
# APR    112345
# MAY    111293
# JUN    109680
# JUL     97909
# AUG     96761
# SEP     94825
# OCT     90353
# NOV     81613
# DEC     72821
# Name: Month_rp, dtype: int64

# %%
def impute(cube, time_cube):
    
    cube['Month'] = time_cube['Month_rp']
    cube['Year'] = time_cube['Year_rp']
    cube['QTRT'] = time_cube['QTRT_rp']
    
    return cube

# %%
df_imputed_uniform = impute(df, df_t_uniform)

# %%
df_imputed_uniform.Month.value_counts()
# Out:
# JAN    105387
# NOV    105382
# AUG    105090
# MAR    105047
# JUL    105047
# DEC    104972
# APR    104970
# MAY    104807
# JUN    104795
# SEP    104742
# OCT    104671
# FEB    104177
# Name: Month, dtype: int64

# %%
def base_structure():
    
    data = pd.read_csv('C:/Users/604070/Desktop/Files/Performance/OPM_HR_Analytics/Dataset/opm_raw.txt', low_memory=False)
    
    data['Year'] = data['EFDATET'].apply(lambda x: x[4:])
    data['Month'] = data['EFDATET'].apply(lambda x: x[:3])
    data['QTRT'] = data['QTRT'].apply(lambda x: x[:7])
    data['GSEGRD'] = data['GSEGRD'].astype(str)
    
    data = data[['AGELVLT', 'AGYSUBT', 'AGYT', 'AGYTYPT',
       'GSEGRD', 'LOCT', 'LOCTYPT', 'LOSLVLT', 'OCCFAMT', 'OCCT', 'PATCOT', 'PAYPLANT', 'PPGRD', 'PPGROUPT', 'QTRT',
       'SALLVLT', 'TOAT', 'TOATYPT', 'WORKSCHT', 'WSTYPT','Year', 'Month']]
    
    return data

# %%
df_truth = base_structure()

# %%
def dummy_data(pred_data, base):
    
    df_combo = pd.concat([pred_data, base], axis = 0)
    
    df_dummy = pd.get_dummies(df_combo)
    
    df_dummy = df_dummy.iloc[:pred_data.shape[0],:]
       
    train_dummy = df_dummy.drop(columns = ['LOCT_MG-MONGOLIA',
    'LOCT_NG-NIGER',
    'GSEGRD_03',
    'LOCT_SL-SIERRA LEONE',
    'GSEGRD_02',
    'LOCT_AU-AUSTRIA',
    'LOCT_UV-BURKINA FASO',
    'LOCT_CE-SRI LANKA',
    'GSEGRD_04',
    'AGYT_GE-BARRY GOLDWATER SCHOLARSHIP AND EXCELLENCE IN EDUCATION FOUNDATION',
    'GSEGRD_09',
    'LOCT_MT-MALTA',
    'LOCT_TD-TRINIDAD AND TOBAGO',
    'LOCT_BM-BURMA',
    'GSEGRD_08',
    'LOCT_HR-CROATIA',
    'AGYSUBT_CM53-BUREAU OF ECONOMIC ANALYSIS',
    'LOCT_RW-RWANDA',
    'GSEGRD_05',
    'LOCT_NZ-NEW ZEALAND',
    'LOCT_NP-NEPAL',
    'LOCT_CM-CAMEROON',
    'LOCT_GV-GUINEA',
    'LOCT_GB-GABON',
    'GSEGRD_07',
    'AGYSUBT_GE00-BARRY GOLDWATER SCHOLARSHIP AND EXCELLENCE IN EDUCATION FOUNDATION',
    'GSEGRD_01',
    'LOCT_LH-LITHUANIA',
    'LOCT_DA-DENMARK',
    'GSEGRD_06'], axis = 1)

    return train_dummy

# %%
df_dummy_uniform = dummy_data(df_imputed_uniform, df_truth)

# %%
df_dummy_uniform.Month_DEC.value_counts()
# Out:
# 0    1154115
# 1     104972
# Name: Month_DEC, dtype: int64

# %%
# models
loaded_model = load_model('saved_model.h5')

# %%
def predict_api(model, data, confidence):
    
    predictions = model.predict(data)
    
    predictions[:,1] = np.where(predictions[:,1] < confidence, 0 , predictions[:,1])
    
    count = predictions.argmax(axis =1).sum()
           
    return count, data.shape[0]

# %%
quits_u, pop = predict_api(loaded_model, df_dummy_uniform, .82)

# %%
quits_u/pop
# Out:
# 0.037419971773197565

# %%
conf = .82

# %%
df_result_uniform = pd.DataFrame(np.zeros((len(df_dummy_uniform.columns), 3)), columns = ['Category', 'Sample_size', 'Predictions_Uniform'])

for i, col in enumerate(df_dummy_uniform.columns): 
     
    try:
        df_result_uniform.iloc[i, 0] = col 
    
        pred_data = df_dummy_uniform[df_dummy_uniform[col]==1]

        quit, sample = predict_api(loaded_model, pred_data, conf)
        
        df_result_uniform.iloc[i,1] = sample
        df_result_uniform.iloc[i,2] = quit
        #print(i)
    
    except:
        print(i,'   ',col, "No entries in the dataset")
# Out:
# 11     AGELVLT_Unspecified No entries in the dataset
# 13     AGYSUBT_AB**-UNSPECIFIED No entries in the dataset
# 47     AGYSUBT_AF2Q-HEADQUARTERS, AIR FORCE WEATHER AGENCY No entries in the dataset
# 55     AGYSUBT_AF3T-AIR FORCE ELEMENTS, U.S. TRANSPORTATION COMMAND No entries in the dataset
# 61     AGYSUBT_AF5K-AIR FORCE PETROLEUM AGENCY No entries in the dataset
# 83     AGYSUBT_AG36-GRAIN INSPECTION, PACKERS AND STOCKYARDS ADMINISTRATION No entries in the dataset
# 119     AGYSUBT_ARG6-U.S. ARMY NETWORK ENTERPRISE TECHNOLOGY COMMAND/9TH ARMY SIGNAL COMMAND No entries in the dataset
# 139     AGYSUBT_ARX1-U.S. ARMY MATERIAL COMMAND No entries in the dataset
# 175     AGYSUBT_CM65-ECONOMICS AND STATISTICS ADMINISTRATION No entries in the dataset
# 202     AGYSUBT_DD68-DEPARTMENT OF DEFENSE TEST RESOURCE MANAGEMENT CENTER No entries in the dataset
# 207     AGYSUBT_DD81-DEFENSE ACQUISITION UNIVERSITY No entries in the dataset
# 249     AGYSUBT_EDEB-OFFICE OF THE DUTY SECRETARY OF EDUCATION No entries in the dataset
# 258     AGYSUBT_EDEL-OFFICE OF THE CHIEF FINANCIAL OFFICER No entries in the dataset
# 259     AGYSUBT_EDEM-OFFICE OF MANAGEMENT No entries in the dataset
# 266     AGYSUBT_EDEU-OFFICE OF INNOVATION AND IMPROVEMENT No entries in the dataset
# 284     AGYSUBT_GM00-VALLES CALDERA TRUST No entries in the dataset
# 295     AGYSUBT_GS18-TECHNOLOGY TRANSFORMATION SERVICE No entries in the dataset
# 314     AGYSUBT_HE31-OFFICE OF THE ASSISTANT SECRETARY FOR HEALTH No entries in the dataset
# 411     AGYSUBT_NV14-OFFICE OF NAVAL RESEARCH No entries in the dataset
# 422     AGYSUBT_NV39-SPACE AND NAVAL WARFARE SYSTEMS COMMAND No entries in the dataset
# 469     AGYSUBT_TRAJ-OFFICE OF THE COMPTROLLER OF THE CURRENCY No entries in the dataset
# 480     AGYSUBT_VAAG-MY VA INITIATIVE No entries in the dataset
# 488     AGYSUBT_VABI-DEAN FOR VA LEARNING UNIVERSITY No entries in the dataset
# 489     AGYSUBT_VABJ-VETERAN EMPLOYMENT SERVICES OFFICE No entries in the dataset
# 501     AGYSUBT_VAHB-DEPUTY ASSISTANT SECRETARY FOR PROGRAM AND DATA ANALYSIS No entries in the dataset
# 502     AGYSUBT_VAHC-DEPUTY ASSISTANT SECRETARY FOR PLANNING AND EVALUATION No entries in the dataset
# 557     AGYT_GM-VALLES CALDERA TRUST No entries in the dataset
# 617     GSEGRD_1 No entries in the dataset
# 624     GSEGRD_2 No entries in the dataset
# 625     GSEGRD_3 No entries in the dataset
# 626     GSEGRD_4 No entries in the dataset
# 627     GSEGRD_5 No entries in the dataset
# 628     GSEGRD_6 No entries in the dataset
# 629     GSEGRD_7 No entries in the dataset
# 630     GSEGRD_8 No entries in the dataset
# 631     GSEGRD_9 No entries in the dataset
# 686     LOCT_AJ-AZERBAIJAN No entries in the dataset
# 688     LOCT_AM-ARMENIA No entries in the dataset
# 689     LOCT_AO-ANGOLA No entries in the dataset
# 693     LOCT_BB-BARBADOS No entries in the dataset
# 698     LOCT_BN-BENIN No entries in the dataset
# 703     LOCT_CD-CHAD No entries in the dataset
# 714     LOCT_EC-ECUADOR No entries in the dataset
# 716     LOCT_EI-IRELAND No entries in the dataset
# 729     LOCT_GY-GUYANA No entries in the dataset
# 746     LOCT_KG-KYRGYZSTAN No entries in the dataset
# 756     LOCT_MD-MOLDOVA No entries in the dataset
# 769     LOCT_NT-NETHERLANDS ANTILLES No entries in the dataset
# 770     LOCT_NU-NICARAGUA No entries in the dataset
# 792     LOCT_TI-TAJIKISTAN No entries in the dataset
# 794     LOCT_TT-TIMOR-LESTE No entries in the dataset
# 801     LOCT_VE-VENEZUELA No entries in the dataset
# 899     OCCT_0243-APPRENTICESHIP AND TRAINING No entries in the dataset
# 926     OCCT_0357-CODING No entries in the dataset
# 980     OCCT_0593-INSURANCE ACCOUNTS No entries in the dataset
# 989     OCCT_0625-AUTOPSY ASSISTANT No entries in the dataset
# 995     OCCT_0637-MANUAL ARTS THERAPIST No entries in the dataset
# 997     OCCT_0639-EDUCATIONAL THERAPIST No entries in the dataset
# 1128     OCCT_1299-COPYRIGHT AND PATENT STUDENT TRAINEE No entries in the dataset
# 1152     OCCT_1386-PHOTOGRAPHIC TECHNOLOGY No entries in the dataset
# 1248     PAYPLANT_GR-GM PHYSICIANS AND DENTISTS PAID MARKET PAY UNDER 38 U.S.C. 7431(C) No entries in the dataset
# 1306     PPGRD_GR-13 No entries in the dataset
# 1307     PPGRD_GR-15 No entries in the dataset
# 1375     TOAT_50-Senior Executive Service - Career No entries in the dataset
# 1376     TOAT_55-Senior Executive Service - Non-Career No entries in the dataset
# 1377     TOAT_60-Senior Executive Service - Limited Term No entries in the dataset
# 1378     TOAT_65-Senior Executive Service - Limited Emergency No entries in the dataset
# 1392     WORKSCHT_T - Part-time Job Sharer Seasonal No entries in the dataset
# 1396     Year_2010 No entries in the dataset
# 1397     Year_2011 No entries in the dataset
# 1398     Year_2012 No entries in the dataset
# 1399     Year_2013 No entries in the dataset
# 1400     Year_2014 No entries in the dataset
# 1401     Year_2015 No entries in the dataset
# 1402     Year_2016 No entries in the dataset

# %%
df_result_uniform.to_csv('uniform_predictions')

# %%
# historical predictions 
df_imputed_historical = impute(df, df_t_historical)

# %%
df_dummy_historical = dummy_data(df_imputed_historical, df_truth)

# %%
df_dummy_historical.Month_DEC.value_counts()
# Out:
# 0    1186266
# 1      72821
# Name: Month_DEC, dtype: int64

# %%
df_result_historical = pd.DataFrame(np.zeros((len(df_dummy_historical.columns), 3)), columns = ['Category', 'Sample_size', 'Predictions_Historical'])

for i, col in enumerate(df_dummy_historical.columns): 
     
    try:
        df_result_historical.iloc[i, 0] = col 
    
        pred_data = df_dummy_historical[df_dummy_historical[col]==1]

        quit, sample = predict_api(loaded_model, pred_data, conf)
        
        df_result_historical.iloc[i,1] = sample
        df_result_historical.iloc[i,2] = quit
        #print(i)
    
    except:
        print(i,'   ',col, "No entries in the dataset")
# Out:
# 11     AGELVLT_Unspecified No entries in the dataset
# 13     AGYSUBT_AB**-UNSPECIFIED No entries in the dataset
# 47     AGYSUBT_AF2Q-HEADQUARTERS, AIR FORCE WEATHER AGENCY No entries in the dataset
# 55     AGYSUBT_AF3T-AIR FORCE ELEMENTS, U.S. TRANSPORTATION COMMAND No entries in the dataset
# 61     AGYSUBT_AF5K-AIR FORCE PETROLEUM AGENCY No entries in the dataset
# 83     AGYSUBT_AG36-GRAIN INSPECTION, PACKERS AND STOCKYARDS ADMINISTRATION No entries in the dataset
# 119     AGYSUBT_ARG6-U.S. ARMY NETWORK ENTERPRISE TECHNOLOGY COMMAND/9TH ARMY SIGNAL COMMAND No entries in the dataset
# 139     AGYSUBT_ARX1-U.S. ARMY MATERIAL COMMAND No entries in the dataset
# 175     AGYSUBT_CM65-ECONOMICS AND STATISTICS ADMINISTRATION No entries in the dataset
# 202     AGYSUBT_DD68-DEPARTMENT OF DEFENSE TEST RESOURCE MANAGEMENT CENTER No entries in the dataset
# 207     AGYSUBT_DD81-DEFENSE ACQUISITION UNIVERSITY No entries in the dataset
# 249     AGYSUBT_EDEB-OFFICE OF THE DUTY SECRETARY OF EDUCATION No entries in the dataset
# 258     AGYSUBT_EDEL-OFFICE OF THE CHIEF FINANCIAL OFFICER No entries in the dataset
# 259     AGYSUBT_EDEM-OFFICE OF MANAGEMENT No entries in the dataset
# 266     AGYSUBT_EDEU-OFFICE OF INNOVATION AND IMPROVEMENT No entries in the dataset
# 284     AGYSUBT_GM00-VALLES CALDERA TRUST No entries in the dataset
# 295     AGYSUBT_GS18-TECHNOLOGY TRANSFORMATION SERVICE No entries in the dataset
# 314     AGYSUBT_HE31-OFFICE OF THE ASSISTANT SECRETARY FOR HEALTH No entries in the dataset
# 411     AGYSUBT_NV14-OFFICE OF NAVAL RESEARCH No entries in the dataset
# 422     AGYSUBT_NV39-SPACE AND NAVAL WARFARE SYSTEMS COMMAND No entries in the dataset
# 469     AGYSUBT_TRAJ-OFFICE OF THE COMPTROLLER OF THE CURRENCY No entries in the dataset
# 480     AGYSUBT_VAAG-MY VA INITIATIVE No entries in the dataset
# 488     AGYSUBT_VABI-DEAN FOR VA LEARNING UNIVERSITY No entries in the dataset
# 489     AGYSUBT_VABJ-VETERAN EMPLOYMENT SERVICES OFFICE No entries in the dataset
# 501     AGYSUBT_VAHB-DEPUTY ASSISTANT SECRETARY FOR PROGRAM AND DATA ANALYSIS No entries in the dataset
# 502     AGYSUBT_VAHC-DEPUTY ASSISTANT SECRETARY FOR PLANNING AND EVALUATION No entries in the dataset
# 557     AGYT_GM-VALLES CALDERA TRUST No entries in the dataset
# 617     GSEGRD_1 No entries in the dataset
# 624     GSEGRD_2 No entries in the dataset
# 625     GSEGRD_3 No entries in the dataset
# 626     GSEGRD_4 No entries in the dataset
# 627     GSEGRD_5 No entries in the dataset
# 628     GSEGRD_6 No entries in the dataset
# 629     GSEGRD_7 No entries in the dataset
# 630     GSEGRD_8 No entries in the dataset
# 631     GSEGRD_9 No entries in the dataset
# 686     LOCT_AJ-AZERBAIJAN No entries in the dataset
# 688     LOCT_AM-ARMENIA No entries in the dataset
# 689     LOCT_AO-ANGOLA No entries in the dataset
# 693     LOCT_BB-BARBADOS No entries in the dataset
# 698     LOCT_BN-BENIN No entries in the dataset
# 703     LOCT_CD-CHAD No entries in the dataset
# 714     LOCT_EC-ECUADOR No entries in the dataset
# 716     LOCT_EI-IRELAND No entries in the dataset
# 729     LOCT_GY-GUYANA No entries in the dataset
# 746     LOCT_KG-KYRGYZSTAN No entries in the dataset
# 756     LOCT_MD-MOLDOVA No entries in the dataset
# 769     LOCT_NT-NETHERLANDS ANTILLES No entries in the dataset
# 770     LOCT_NU-NICARAGUA No entries in the dataset
# 792     LOCT_TI-TAJIKISTAN No entries in the dataset
# 794     LOCT_TT-TIMOR-LESTE No entries in the dataset
# 801     LOCT_VE-VENEZUELA No entries in the dataset
# 899     OCCT_0243-APPRENTICESHIP AND TRAINING No entries in the dataset
# 926     OCCT_0357-CODING No entries in the dataset
# 980     OCCT_0593-INSURANCE ACCOUNTS No entries in the dataset
# 989     OCCT_0625-AUTOPSY ASSISTANT No entries in the dataset
# 995     OCCT_0637-MANUAL ARTS THERAPIST No entries in the dataset
# 997     OCCT_0639-EDUCATIONAL THERAPIST No entries in the dataset
# 1128     OCCT_1299-COPYRIGHT AND PATENT STUDENT TRAINEE No entries in the dataset
# 1152     OCCT_1386-PHOTOGRAPHIC TECHNOLOGY No entries in the dataset
# 1248     PAYPLANT_GR-GM PHYSICIANS AND DENTISTS PAID MARKET PAY UNDER 38 U.S.C. 7431(C) No entries in the dataset
# 1306     PPGRD_GR-13 No entries in the dataset
# 1307     PPGRD_GR-15 No entries in the dataset
# 1375     TOAT_50-Senior Executive Service - Career No entries in the dataset
# 1376     TOAT_55-Senior Executive Service - Non-Career No entries in the dataset
# 1377     TOAT_60-Senior Executive Service - Limited Term No entries in the dataset
# 1378     TOAT_65-Senior Executive Service - Limited Emergency No entries in the dataset
# 1392     WORKSCHT_T - Part-time Job Sharer Seasonal No entries in the dataset
# 1396     Year_2010 No entries in the dataset
# 1397     Year_2011 No entries in the dataset
# 1398     Year_2012 No entries in the dataset
# 1399     Year_2013 No entries in the dataset
# 1400     Year_2014 No entries in the dataset
# 1401     Year_2015 No entries in the dataset
# 1402     Year_2016 No entries in the dataset

# %%
df_result_historical.to_csv('historical_predictions')

# %%
df_uni = pd.read_csv('uniform_predictions')
df_hist = pd.read_csv('historical_predictions')

# %%
df_uni = df_uni.iloc[:,1:]
df_hist = df_hist.iloc[:,1:]

# %%
df_uni.head()
# Out:
#         Category  Sample_size  Predictions_Uniform
# 0  AGELVLT_20-24      24738.0               3088.0
# 1  AGELVLT_25-29      62577.0               7077.0
# 2  AGELVLT_30-34     117116.0              10520.0
# 3  AGELVLT_35-39     158801.0              10259.0
# 4  AGELVLT_40-44     149072.0               6441.0

# %%
df_hist.head()
# Out:
#         Category  Sample_size  Predictions_Historical
# 0  AGELVLT_20-24      24738.0                  3134.0
# 1  AGELVLT_25-29      62577.0                  7208.0
# 2  AGELVLT_30-34     117116.0                 10778.0
# 3  AGELVLT_35-39     158801.0                 10254.0
# 4  AGELVLT_40-44     149072.0                  6531.0

# %%
df_final = df_uni.join(df_hist, rsuffix = 'historical')

# %%
df_final
# Out:
#                                                Category  Sample_size  \
# 0                                         AGELVLT_20-24      24738.0
# 1                                         AGELVLT_25-29      62577.0
# 2                                         AGELVLT_30-34     117116.0
# 3                                         AGELVLT_35-39     158801.0
# 4                                         AGELVLT_40-44     149072.0
# 5                                         AGELVLT_45-49     164902.0
# 6                                         AGELVLT_50-54     193709.0
# 7                                         AGELVLT_55-59     196591.0
# 8                                         AGELVLT_60-64     121792.0
# 9                                    AGELVLT_65 or more      67264.0
# 10                                 AGELVLT_Less than 20       2525.0
# 11                                  AGELVLT_Unspecified          0.0
# 12    AGYSUBT_AA00-ADMINISTRATIVE CONFERENCE OF THE ...          9.0
# 13                             AGYSUBT_AB**-UNSPECIFIED          0.0
# 14    AGYSUBT_AB00-AMERICAN BATTLE MONUMENTS COMMISSION         80.0
# 15        AGYSUBT_AF02-AIR FORCE INSPECTION AGENCY (FO)         20.0
# 16    AGYSUBT_AF03-AIR FORCE OPERATIONAL TEST AND EV...        232.0
# 17                  AGYSUBT_AF06-AIR FORCE AUDIT AGENCY        581.0
# 18    AGYSUBT_AF07-AIR FORCE OFFICE OF SPECIAL INVES...        296.0
# 19              AGYSUBT_AF09-AIR FORCE PERSONNEL CENTER       1341.0
# 20                  AGYSUBT_AF0B-U.S. AIR FORCE ACADEMY        750.0
# 21                 AGYSUBT_AF0D-U.S. AIR FORCES, EUROPE       1529.0
# 22      AGYSUBT_AF0J-AIR EDUCATION AND TRAINING COMMAND      11434.0
# 23    AGYSUBT_AF0M-HEADQUARTERS, AIR FORCE RESERVE C...       6814.0
# 24                      AGYSUBT_AF0R-PACIFIC AIR FORCES       2328.0
# 25                                   AGYSUBT_AF0U-25 AF          1.0
# 26    AGYSUBT_AF0V-AIR FORCE SPECIAL OPERATIONS COMMAND       1519.0
# 27         AGYSUBT_AF12-AIR FORCE PUBLIC AFFAIRS AGENCY         33.0
# 1395                    8.0                     2.0
# 1396                    0.0                     0.0
# 1397                    0.0                     0.0
# 1398                    0.0                     0.0
# 1399                    0.0                     0.0
# 1400                    0.0                     0.0
# 1401                    0.0                     0.0
# 1402                    0.0                     0.0
# 1403              1259087.0                 47805.0
# 1404               112345.0                  3822.0
# 1405                96761.0                  4195.0
# 1406                72821.0                  2376.0
# 1407               126486.0                  3532.0
# 1408               142761.0                  2244.0
# 1409                97909.0                  4496.0
# 1410               109680.0                  6010.0
# 1411               122240.0                  9262.0
# 1412               111293.0                  5386.0
# 1413                81613.0                  1671.0
# 1414                90353.0                  2327.0
# 1415                94825.0                  2484.0
#
# [1416 rows x 6 columns]

# %%
df_final.columns
# Out:
# Index(['Category', 'Sample_size', 'Predictions_Uniform', 'Categoryhistorical',
#        'Sample_sizehistorical', 'Predictions_Historical'],
#       dtype='object')

# %%
df_final.sort_values(['Category'], ascending = [True]).head()
# Out:
#         Category  Sample_size  Predictions_Uniform Categoryhistorical  \
# 0  AGELVLT_20-24      24738.0               3088.0      AGELVLT_20-24
# 1  AGELVLT_25-29      62577.0               7077.0      AGELVLT_25-29
# 2  AGELVLT_30-34     117116.0              10520.0      AGELVLT_30-34
# 3  AGELVLT_35-39     158801.0              10259.0      AGELVLT_35-39
# 4  AGELVLT_40-44     149072.0               6441.0      AGELVLT_40-44
#
#    Sample_sizehistorical  Predictions_Historical
# 0                24738.0                  3134.0
# 1                62577.0                  7208.0
# 2               117116.0                 10778.0
# 3               158801.0                 10254.0
# 4               149072.0                  6531.0

# %%
df_final = df_final[['Category', 'Predictions_Historical', 'Predictions_Uniform', 'Sample_size']]

# %%
df_final.head()
# Out:
#         Category  Predictions_Historical  Predictions_Uniform  Sample_size
# 0  AGELVLT_20-24                  3134.0               3088.0      24738.0
# 1  AGELVLT_25-29                  7208.0               7077.0      62577.0
# 2  AGELVLT_30-34                 10778.0              10520.0     117116.0
# 3  AGELVLT_35-39                 10254.0              10259.0     158801.0
# 4  AGELVLT_40-44                  6531.0               6441.0     149072.0

# %%
df_final = df_final[df_final['Sample_size'] > 0]

# %%
df_final = df_final.set_index('Category')

# %%
df_final.drop(['Year_2017', 
           'Month_APR', 
           'Month_AUG', 
           'Month_DEC', 
           'Month_FEB',
           'Month_JAN', 
           'Month_JUL',
           'Month_JUN', 
           'Month_MAR', 
           'Month_MAY', 
           'Month_NOV', 
           'Month_OCT', 
           'Month_SEP', 
           'QTRT_JAN-MAR', 
           'QTRT_APR-JUN',
           'QTRT_JUL-SEP',
           'GSEGRD_10',
           'GSEGRD_11',
           'GSEGRD_12',
           'GSEGRD_13',
           'GSEGRD_14',
           'GSEGRD_15',
            'QTRT_OCT-DEC'], axis = 0, inplace=True)

# %%
df_final.sort_values(['Sample_size'], ascending = False, inplace =True)
df_final.shape
# Out:
# (1318, 3)

# %%
df_final
# Out:
#                                                     Predictions_Historical  \
# Category
# LOCTYPT_United States                                              47248.0
# PPGROUPT_Standard GSEG Pay Plans                                   46186.0
# PAYPLANT_GS-GENERAL SCHEDULE                                       45903.0
# WSTYPT_Full-time                                                   37506.0
# WORKSCHT_F - Full-time Nonseasonal                                 32353.0
# WSTYPT_Full-time                                      1213694.0
# WORKSCHT_F - Full-time Nonseasonal                    1193506.0
# TOATYPT_Permanent                                     1181056.0
# AGYTYPT_Cabinet Level Agencies                        1120488.0
# TOAT_10-Competitive Service - Career                   805457.0
# PATCOT_Administrative                                  525416.0
# PATCOT_Professional                                    323387.0
# PATCOT_Technical                                       289502.0
# OCCFAMT_03xx-GENERAL ADMIN, CLERICAL, & OFFICE ...     256559.0
# LOSLVLT_5 - 9 years                                    244993.0
# AGYT_VA-DEPARTMENT OF VETERANS AFFAIRS                 243936.0
# LOSLVLT_10 - 14 years                                  237648.0
# PPGRD_GS-12                                            222987.0
# AGYSUBT_VATA-VETERANS HEALTH ADMINISTRATION            207203.0
# AGELVLT_55-59                                          196591.0
# AGELVLT_50-54                                          193709.0
# PPGRD_GS-13                                            186818.0
# OCCFAMT_06xx-MEDICAL, HOSPITAL, DENTAL & PUB HE...     186619.0
# TOAT_38-Excepted Service - Other                       183550.0
# PPGRD_GS-11                                            171053.0
# AGYT_AR-DEPARTMENT OF THE ARMY                         164938.0
# AGELVLT_45-49                                          164902.0
# AGELVLT_35-39                                          158801.0
# AGELVLT_40-44                                          149072.0
# LOSLVLT_15 - 19 years                                  147334.0
# SALLVLT_$40,000 - $49,999                              147009.0
# SALLVLT_$50,000 - $59,999                              143048.0
# ...                                                         ...
# LOCT_BG-BANGLADESH                                          2.0
# LOCT_BK-BOSNIA AND HERZEGOVINA                              2.0
# LOCT_BR-BRAZIL                                              2.0
# LOCT_CB-CAMBODIA                                            2.0
# LOCT_CF-CONGO                                               2.0
# LOCT_KV-KOSOVO                                              2.0
# LOCT_DR-DOMINICAN REPUBLIC                                  2.0
# LOCT_IC-ICELAND                                             2.0
# LOCT_EN-ESTONIA                                             2.0
# LOCT_HK-HONG KONG                                           2.0
# LOCT_CI-CHILE                                               2.0
# AGYSUBT_CE00-COUNCIL OF ECONOMIC ADVISERS                   1.0
# AGYSUBT_AF2A-AIR FORCE COST ANALYSIS AGENCY                 1.0
# AGYSUBT_AF0U-25 AF                                          1.0
# PPGRD_GG-01                                                 1.0
# TOAT_46-Excepted Service - Executive                        1.0
# AGYSUBT_KS00-CORPORATION FOR NATIONAL AND COMMU...          1.0
# TOAT_36-Excepted Service - Executive                        1.0
# AGYT_CE-COUNCIL OF ECONOMIC ADVISERS                        1.0
# SALLVLT_Less than $20,000                                   1.0
# AGYT_KS-CORPORATION FOR NATIONAL AND COMMUNITY ...          1.0
# LOCT_DJ-DJIBOUTI                                            1.0
# PPGRD_PG-10                                                 1.0
# LOCT_MK-MACEDONIA                                           1.0
# LOCT_PA-PARAGUAY                                            1.0
# LOCT_SU-SUDAN                                               1.0
# OCCT_1021-OFFICE DRAFTING                                   1.0
# OCCT_1521-MATHEMATICS TECHNICIAN                            1.0
# OCCT_2199-TRANSPORTATION STUDENT TRAINEE                    1.0
# LOCT_GL-GREENLAND                                           1.0
#
# [1318 rows x 3 columns]

# %%
df_final.to_csv('publish_version_4_30_20.csv')

# %%
sum(df_final.Predictions_Historical) / sum(df_final.Sample_size)
# Out:
# 0.03796804655020438
